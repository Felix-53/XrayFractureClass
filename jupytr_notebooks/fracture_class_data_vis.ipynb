# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
sns.set_style("white")
from matplotlib.image import imread

# %%
work_dir = os.getcwd()
work_dir
# Out:
# '/workspaces/XrayFractureClass/jupytr_notebooks'

# %%
my_data_dir = '../data/test/'
train_path = my_data_dir + '/train'
val_path = my_data_dir + '/validation'
test_path = my_data_dir + '/test'

# %%
version = 'v1'
file_path = f'outputs/{version}'

if 'outputs' in os.listdir(work_dir) and version in os.listdir(work_dir + '/outputs'):
    print('Old version is already available create a new version.')
    pass
else:
    os.makedirs(name=file_path)
# Out:
# Old version is already available create a new version.

# %%
labels = os.listdir(train_path)
print('Label for the images are', labels)
# Out:
# Label for the images are ['normal', 'fracture']

# %%
ls /workspaces/XrayFractureClass/data/raw/Bone_Fracture_Binary_Classification/Bone_Fracture_Binary_Classification/
# Out:
# test/  train/  val/

# %%
train_path ='/workspaces/XrayFractureClass/data/raw/Bone_Fracture_Binary_Classification/Bone_Fracture_Binary_Classificatio/train'
labels = os.listdir(train_path)

dim1, dim2 = [], []
for label in labels:
    label_path = os.path.join(train_path, label)
    if not os.path.isdir(label_path):
        continue
    for image_filename in os.listdir(label_path):
        img_path = os.path.join(label_path, image_filename)
        img = imread(img_path)
        if img.dim == 2:
            d1, d2 = img.shape
        else:
            d1, d2, _ = img.shape 

sns.set_style("whitegrid")
fig, axes = plt.subplots()
sns.scatterplot(x=dim2, y=dim1, alpha=0.2)
axes.set_xlabel("Width (pixels)")
axes.set_ylabel("Height (pixels)")
dim1_mean = int(np.array(dim1).mean())
dim2_mean = int(np.array(dim2).mean())
axes.axhline(y=dim2_mean, color='r', linestyle='--')
axes.axvline(x=dim1_mean, color='r', linestyle='--')
plt.show()
print(f"Width average: {dim2_mean} \nHeight average: {dim1_mean}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[24], line 2
#       1 train_path ='/workspaces/XrayFractureClass/data/raw/Bone_Fracture_Binary_Classification/Bone_Fracture_Binary_Classificatio/train'
# ----> 2 labels = os.listdir(train_path)
#       4 dim1, dim2 = [], []
#       5 for label in labels:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/workspaces/XrayFractureClass/data/raw/Bone_Fracture_Binary_Classification/Bone_Fracture_Binary_Classificatio/train'
